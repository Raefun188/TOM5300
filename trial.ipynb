# %%
print("hello world!")
# Out:
# hello world!

# %%
# Dictionary of popular US girls' names (name: rank)
popular_girls_names = {
    "Olivia": 1,
    "Emma": 2,
    "Charlotte": 3,
    "Amelia": 4,
    "Ava": 5,
    "Sophia": 6,
    "Isabella": 7,
    "Mia": 8,
    "Evelyn": 9,
    "Harper": 10,
    "Luna": 11,
    "Camila": 12,
    "Gianna": 13,
    "Elizabeth": 14,
    "Eleanor": 15,
    "Ella": 16,
    "Abigail": 17,
    "Sofia": 18,
    "Avery": 19,
    "Scarlett": 20
}
